# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %% [markdown]
# ## 데이터 설명
# - 리그오브레전드 14시즌 솔로랭크 마스터 ~ 챌린저 구간 무작위 매치 데이터 약 12000건

# %%
data = pd.read_csv('preprocessed_data2.csv', index_col=0)

# %%
data
# Out:
#       metadata.matchId  blue_win  blue_objectives.baron.first  \
# 0        KR_6897835155     False                        False
# 1        KR_6900635803      True                        False
# 2        KR_6903010835      True                         True
# 3        KR_6897507607     False                        False
# 4        KR_6894687696     False                        False
# ...                ...       ...                          ...
# 12363    KR_6897632585     False                        False
# 12364    KR_6913727391      True                        False
# 12365    KR_6894562023      True                         True
# 12366    KR_6894562023      True                         True
# 12367    KR_6906809129     False                        False
#
#        blue_objectives.baron.kills  blue_objectives.champion.first  \
# 0                                0                           False
# 1                                0                           False
# 2                                1                            True
# 3                                0                            True
# 4                                0                           False
# ...                            ...                             ...
# 12363                            0                           False
# 12364                            0                            True
# 12365                            2                            True
# 12366                            2                            True
# 12367                            0                           False
#
#        blue_objectives.champion.kills  blue_objectives.dragon.first  \
# 0                                  23                         False
# 1                                  36                         False
# 2                                  38                         False
# 3                                  40                          True
# 4                                   7                         False
# ...                               ...                           ...
# 12363                              23                         False
# 12364                              18                          True
# 12365                              48                          True
# 12366                              48                          True
# 12367                               7                         False
#
#        blue_objectives.dragon.kills  blue_objectives.horde.first  \
# 0                                 2                         True
# 1                                 2                         True
# 2                                 2                         True
# 3                                 2                         True
# 4                                 0                         True
# ...                             ...                          ...
# 12363                             0                        False
# 12364                             2                         True
# 12365                             3                        False
# 12366                             3                        False
# 12367                             0                        False
#
#        blue_objectives.horde.kills  ...  red_objectives.tower.first  \
# 0                                6  ...                       False
# 1                                6  ...                       False
# 2                                6  ...                       False
# 3                                5  ...                       False
# 4                                3  ...                        True
# ...                            ...  ...                         ...
# 12363                            1  ...                        True
# 12364                            6  ...                       False
# 12365                            0  ...                        True
# 12366                            0  ...                        True
# 12367                            1  ...                        True
#
#        red_objectives.tower.kills  horde_kills  index  blue_ping  red_ping  \
# 0                               8            6      0       29.4     108.2
# 1                               1            6      0       44.4      23.0
# 2                               2            6      0       41.4      36.0
# 3                              11            4      0       57.6      46.8
# 4                               4            0      0       17.6      11.4
# ...                           ...          ...    ...        ...       ...
# 12363                          10           -4      0       23.6      57.8
# 12364                           0            6      0       19.2      15.6
# 12365                           4           -6      0       55.6      69.8
# 12366                           4           -6      0       55.6      69.8
# 12367                           3           -4      0       22.4      16.4
#
#        blue_visionScore  blue_visionWardsBoughtInGame  red_visionScore  \
# 0                  36.2                           5.2             48.0
# 1                  29.8                           4.2             25.0
# 2                  32.4                           2.6             34.2
# 3                  46.2                           4.0             40.2
# 4                  10.6                           1.6             16.4
# ...                 ...                           ...              ...
# 12363              25.2                           2.8             38.4
# 12364              14.2                           2.6             12.4
# 12365              40.0                           5.2             40.8
# 12366              40.0                           5.2             40.8
# 12367              11.4                           1.8             15.2
#
#        red_visionWardsBoughtInGame
# 0                              3.0
# 1                              2.4
# 2                              3.4
# 3                              4.8
# 4                              1.2
# ...                            ...
# 12363                          5.2
# 12364                          0.6
# 12365                          4.6
# 12366                          4.6
# 12367                          1.8
#
# [12368 rows x 38 columns]

# %% [markdown]
# ## 가설
# - 시즌이 바뀌고 협곡의 변화가 생김으로 인해서 레드팀의 승률이 낮을 것이라 예상
# - 상위 티어이므로 핑이 제 역할을 하여 핑을 많이 찍을수록 승률이 높을 것이다.
# - 시야는 게임에서 가장 중요한 요소 중 하나이므로 모든 요소에 높은 상관관계를 갖고 있을 것이다
# - 새로생긴 공허유충의 효과로 인해서 용보다 유충을 상대보다 많이 먹을 수록 승률이 높아질 것이다

# %%
sns.countplot(data, x=data.blue_win, hue=data.blue_win)
# Out:
# /Users/raphaelseo/Library/Caches/pypoetry/virtualenvs/data-analysis-GxIBxRoh-py3.10/lib/python3.10/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/raphaelseo/Library/Caches/pypoetry/virtualenvs/data-analysis-GxIBxRoh-py3.10/lib/python3.10/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='blue_win', ylabel='count'>

# %% [markdown]
# ### 승률 가설
# - 레드팀 바텀이 힘들어졌다고 생각하여 승률이 낮을 것이라 예상했지만, 무작위로 뽑은 데이터 약 12000건을 분석한 결과 레드팀의 승률이 높았음

# %%
data = data.drop(['metadata.matchId', 'index'], axis=1)

# %%
data = data.drop(['blue_objectives.horde.kills', 'red_objectives.horde.kills'],axis=1)

# %% [markdown]
# ### Feature Engineering

# %%
# 와드 구매 데이터를 각 팀의 갯수를 뺴서 하나의 컬럼으로 변경
data['ward_diff'] = data['blue_visionWardsBoughtInGame'] - data['red_visionWardsBoughtInGame']

# %%
data = data.drop(['blue_visionWardsBoughtInGame', 'red_visionWardsBoughtInGame'], axis=1)

# %%
data.columns
# Out:
# Index(['blue_win', 'blue_objectives.baron.first',
#        'blue_objectives.baron.kills', 'blue_objectives.champion.first',
#        'blue_objectives.champion.kills', 'blue_objectives.dragon.first',
#        'blue_objectives.dragon.kills', 'blue_objectives.horde.first',
#        'blue_objectives.inhibitor.first', 'blue_objectives.inhibitor.kills',
#        'blue_objectives.riftHerald.first', 'blue_objectives.riftHerald.kills',
#        'blue_objectives.tower.first', 'blue_objectives.tower.kills',
#        'red_objectives.baron.first', 'red_objectives.baron.kills',
#        'red_objectives.champion.first', 'red_objectives.champion.kills',
#        'red_objectives.dragon.first', 'red_objectives.dragon.kills',
#        'red_objectives.horde.first', 'red_objectives.inhibitor.first',
#        'red_objectives.inhibitor.kills', 'red_objectives.riftHerald.first',
#        'red_objectives.riftHerald.kills', 'red_objectives.tower.first',
#        'red_objectives.tower.kills', 'horde_kills', 'blue_ping', 'red_ping',
#        'blue_visionScore', 'red_visionScore', 'ward_diff'],
#       dtype='object')

# %%
# 시야점수도 마찬가지로 팀의 차이로 변경하여 컬럼을 줄임
data['vision_score_diff'] = data['blue_visionScore'] - data['red_visionScore']

# %%
data = data.drop(['blue_visionScore', 'red_visionScore'], axis=1)

# %%
# 전령을 처음 죽이는 것과 죽인 횟수는 동일함으로 하나를 제거
data = data.drop(['blue_objectives.riftHerald.first', 'red_objectives.riftHerald.first'], axis=1)

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
# 각각의 컬럼을 팀별로 구분되어 있어 이를 팀별 차이로 변환
wins = data[['blue_win', 'horde_kills', 'ward_diff', 'vision_score_diff']]
blue = data.filter(regex='blue_.*')
red = data.filter(regex='red_.*')

# %%
wins
# Out:
#        blue_win  horde_kills  ward_diff  vision_score_diff
# 0         False            6        2.2              -11.8
# 1          True            6        1.8                4.8
# 2          True            6       -0.8               -1.8
# 3         False            4       -0.8                6.0
# 4         False            0        0.4               -5.8
# ...         ...          ...        ...                ...
# 12363     False           -4       -2.4              -13.2
# 12364      True            6        2.0                1.8
# 12365      True           -6        0.6               -0.8
# 12366      True           -6        0.6               -0.8
# 12367     False           -4        0.0               -3.8
#
# [12368 rows x 4 columns]

# %%
blue = blue.drop('blue_win', axis=1)

# %%
blue
# Out:
#        blue_objectives.baron.first  blue_objectives.baron.kills  \
# 0                            False                            0
# 1                            False                            0
# 2                             True                            1
# 3                            False                            0
# 4                            False                            0
# ...                            ...                          ...
# 12363                        False                            0
# 12364                        False                            0
# 12365                         True                            2
# 12366                         True                            2
# 12367                        False                            0
#
#        blue_objectives.champion.first  blue_objectives.champion.kills  \
# 0                               False                              23
# 1                               False                              36
# 2                                True                              38
# 3                                True                              40
# 4                               False                               7
# ...                               ...                             ...
# 12363                           False                              23
# 12364                            True                              18
# 12365                            True                              48
# 12366                            True                              48
# 12367                           False                               7
#
#        blue_objectives.dragon.first  blue_objectives.dragon.kills  \
# 0                             False                             2
# 1                             False                             2
# 2                             False                             2
# 3                              True                             2
# 4                             False                             0
# ...                             ...                           ...
# 12363                         False                             0
# 12364                          True                             2
# 12365                          True                             3
# 12366                          True                             3
# 12367                         False                             0
#
#        blue_objectives.horde.first  blue_objectives.inhibitor.first  \
# 0                             True                            False
# 1                             True                             True
# 2                             True                             True
# 3                             True                            False
# 4                             True                            False
# ...                            ...                              ...
# 12363                        False                            False
# 12364                         True                            False
# 12365                        False                             True
# 12366                        False                             True
# 12367                        False                            False
#
#        blue_objectives.inhibitor.kills  blue_objectives.riftHerald.kills  \
# 0                                    0                                 1
# 1                                    1                                 1
# 2                                    2                                 1
# 3                                    0                                 0
# 4                                    0                                 0
# ...                                ...                               ...
# 12363                                0                                 0
# 12364                                0                                 1
# 12365                                1                                 0
# 12366                                1                                 0
# 12367                                0                                 0
#
#        blue_objectives.tower.first  blue_objectives.tower.kills  blue_ping
# 0                             True                            4       29.4
# 1                             True                            7       44.4
# 2                             True                            8       41.4
# 3                             True                            7       57.6
# 4                            False                            0       17.6
# ...                            ...                          ...        ...
# 12363                        False                            1       23.6
# 12364                         True                            6       19.2
# 12365                        False                            7       55.6
# 12366                        False                            7       55.6
# 12367                        False                            0       22.4
#
# [12368 rows x 13 columns]

# %%
blue = data[[c for c in data.columns if "blue" in c]]

# %%
diff = blue.to_numpy() - red.to_numpy()

# %%
diff
# Out:
# array([[-1, -2, -1, ..., 1, -4, -78.80000000000001],
#        [0, 0, -1, ..., 1, 6, 21.4],
#        [1, 1, 1, ..., 1, 6, 5.399999999999999],
#        ...,
#        [1, 2, 1, ..., -1, 3, -14.20000000000001],
#        [1, 2, 1, ..., -1, 3, -14.20000000000001],
#        [0, 0, -1, ..., -1, -3, 5.9999999999999964]], dtype=object)

# %%
diff_columns = [x[4:] + "_diff" for x in red.columns]

# %%
diff_columns
# Out:
# ['objectives.baron.first_diff',
#  'objectives.baron.kills_diff',
#  'objectives.champion.first_diff',
#  'objectives.champion.kills_diff',
#  'objectives.dragon.first_diff',
#  'objectives.dragon.kills_diff',
#  'objectives.horde.first_diff',
#  'objectives.inhibitor.first_diff',
#  'objectives.inhibitor.kills_diff',
#  'objectives.riftHerald.kills_diff',
#  'objectives.tower.first_diff',
#  'objectives.tower.kills_diff',
#  'ping_diff']

# %%
diff_df = pd.DataFrame(diff, columns=diff_columns)

# %%
diff_df
# Out:
#       objectives.baron.first_diff objectives.baron.kills_diff  \
# 0                              -1                          -2
# 1                               0                           0
# 2                               1                           1
# 3                              -1                          -2
# 4                               0                           0
# ...                           ...                         ...
# 12363                          -1                          -1
# 12364                           0                           0
# 12365                           1                           2
# 12366                           1                           2
# 12367                           0                           0
#
#       objectives.champion.first_diff objectives.champion.kills_diff  \
# 0                                 -1                            -15
# 1                                 -1                             19
# 2                                  1                             29
# 3                                  1                            -11
# 4                                 -1                            -12
# ...                              ...                            ...
# 12363                             -1                            -18
# 12364                              1                             12
# 12365                              1                             24
# 12366                              1                             24
# 12367                             -1                            -15
#
#       objectives.dragon.first_diff objectives.dragon.kills_diff  \
# 0                               -1                           -1
# 1                               -1                            1
# 2                               -1                           -1
# 3                                1                           -1
# 4                               -1                           -2
# ...                            ...                          ...
# 12363                           -1                           -3
# 12364                            1                            2
# 12365                            1                            2
# 12366                            1                            2
# 12367                           -1                           -1
#
#       objectives.horde.first_diff objectives.inhibitor.first_diff  \
# 0                               1                              -1
# 1                               1                               1
# 2                               1                               1
# 3                               1                              -1
# 4                               1                               0
# ...                           ...                             ...
# 12363                          -1                              -1
# 12364                           1                               0
# 12365                          -1                               1
# 12366                          -1                               1
# 12367                          -1                               0
#
#       objectives.inhibitor.kills_diff objectives.riftHerald.kills_diff  \
# 0                                  -2                                1
# 1                                   1                                1
# 2                                   2                                1
# 3                                  -3                               -1
# 4                                   0                                0
# ...                               ...                              ...
# 12363                              -2                               -1
# 12364                               0                                1
# 12365                               1                               -1
# 12366                               1                               -1
# 12367                               0                               -1
#
#       objectives.tower.first_diff objectives.tower.kills_diff ping_diff
# 0                               1                          -4     -78.8
# 1                               1                           6      21.4
# 2                               1                           6       5.4
# 3                               1                          -4      10.8
# 4                              -1                          -4       6.2
# ...                           ...                         ...       ...
# 12363                          -1                          -9     -34.2
# 12364                           1                           6       3.6
# 12365                          -1                           3     -14.2
# 12366                          -1                           3     -14.2
# 12367                          -1                          -3       6.0
#
# [12368 rows x 13 columns]

# %%
data_diff = pd.concat([wins, diff_df], axis=1)

# %%
data_diff
# Out:
#        blue_win  horde_kills  ward_diff  vision_score_diff  \
# 0         False            6        2.2              -11.8
# 1          True            6        1.8                4.8
# 2          True            6       -0.8               -1.8
# 3         False            4       -0.8                6.0
# 4         False            0        0.4               -5.8
# ...         ...          ...        ...                ...
# 12363     False           -4       -2.4              -13.2
# 12364      True            6        2.0                1.8
# 12365      True           -6        0.6               -0.8
# 12366      True           -6        0.6               -0.8
# 12367     False           -4        0.0               -3.8
#
#       objectives.baron.first_diff objectives.baron.kills_diff  \
# 0                              -1                          -2
# 1                               0                           0
# 2                               1                           1
# 3                              -1                          -2
# 4                               0                           0
# ...                           ...                         ...
# 12363                          -1                          -1
# 12364                           0                           0
# 12365                           1                           2
# 12366                           1                           2
# 12367                           0                           0
#
#       objectives.champion.first_diff objectives.champion.kills_diff  \
# 0                                 -1                            -15
# 1                                 -1                             19
# 2                                  1                             29
# 3                                  1                            -11
# 4                                 -1                            -12
# ...                              ...                            ...
# 12363                             -1                            -18
# 12364                              1                             12
# 12365                              1                             24
# 12366                              1                             24
# 12367                             -1                            -15
#
#       objectives.dragon.first_diff objectives.dragon.kills_diff  \
# 0                               -1                           -1
# 1                               -1                            1
# 2                               -1                           -1
# 3                                1                           -1
# 4                               -1                           -2
# ...                            ...                          ...
# 12363                           -1                           -3
# 12364                            1                            2
# 12365                            1                            2
# 12366                            1                            2
# 12367                           -1                           -1
#
#       objectives.horde.first_diff objectives.inhibitor.first_diff  \
# 0                               1                              -1
# 1                               1                               1
# 2                               1                               1
# 3                               1                              -1
# 4                               1                               0
# ...                           ...                             ...
# 12363                          -1                              -1
# 12364                           1                               0
# 12365                          -1                               1
# 12366                          -1                               1
# 12367                          -1                               0
#
#       objectives.inhibitor.kills_diff objectives.riftHerald.kills_diff  \
# 0                                  -2                                1
# 1                                   1                                1
# 2                                   2                                1
# 3                                  -3                               -1
# 4                                   0                                0
# ...                               ...                              ...
# 12363                              -2                               -1
# 12364                               0                                1
# 12365                               1                               -1
# 12366                               1                               -1
# 12367                               0                               -1
#
#       objectives.tower.first_diff objectives.tower.kills_diff ping_diff
# 0                               1                          -4     -78.8
# 1                               1                           6      21.4
# 2                               1                           6       5.4
# 3                               1                          -4      10.8
# 4                              -1                          -4       6.2
# ...                           ...                         ...       ...
# 12363                          -1                          -9     -34.2
# 12364                           1                           6       3.6
# 12365                          -1                           3     -14.2
# 12366                          -1                           3     -14.2
# 12367                          -1                          -3       6.0
#
# [12368 rows x 17 columns]

# %%
data_diff.corr()
# Out:
#                                   blue_win  horde_kills  ward_diff  \
# blue_win                          1.000000     0.270790   0.162248
# horde_kills                       0.270790     1.000000   0.130632
# ward_diff                         0.162248     0.130632   1.000000
# vision_score_diff                 0.491109     0.213825   0.281629
# objectives.baron.first_diff       0.549484     0.098641   0.113357
# objectives.baron.kills_diff       0.571851     0.089052   0.109734
# objectives.champion.first_diff    0.209457     0.178579   0.083377
# objectives.champion.kills_diff    0.844246     0.281182   0.219527
# objectives.dragon.first_diff      0.243997     0.026022   0.104373
# objectives.dragon.kills_diff      0.575152     0.149250   0.170814
# objectives.horde.first_diff       0.100173     0.657438   0.059074
# objectives.inhibitor.first_diff   0.707649     0.204648   0.119368
# objectives.inhibitor.kills_diff   0.698330     0.193885   0.107689
# objectives.riftHerald.kills_diff  0.341810     0.274709   0.123460
# objectives.tower.first_diff       0.430941     0.331422   0.118371
# objectives.tower.kills_diff       0.854963     0.307107   0.158375
# ping_diff                         0.309015     0.116982   0.164038
#
#                                   vision_score_diff  \
# blue_win                                   0.491109
# horde_kills                                0.213825
# ward_diff                                  0.281629
# vision_score_diff                          1.000000
# objectives.baron.first_diff                0.358299
# objectives.baron.kills_diff                0.371451
# objectives.champion.first_diff             0.128507
# objectives.champion.kills_diff             0.522768
# objectives.dragon.first_diff               0.188003
# objectives.dragon.kills_diff               0.428928
# objectives.horde.first_diff                0.084155
# objectives.inhibitor.first_diff            0.442314
# objectives.inhibitor.kills_diff            0.450561
# objectives.riftHerald.kills_diff           0.243571
# objectives.tower.first_diff                0.313140
# objectives.tower.kills_diff                0.526480
# ping_diff                                  0.220722
#
#                                   objectives.baron.first_diff  \
# blue_win                                             0.549484
# horde_kills                                          0.098641
# ward_diff                                            0.113357
# vision_score_diff                                    0.358299
# objectives.baron.first_diff                          1.000000
# objectives.baron.kills_diff                          0.889625
# objectives.champion.first_diff                       0.092570
# objectives.champion.kills_diff                       0.521553
# objectives.dragon.first_diff                         0.097870
# objectives.dragon.kills_diff                         0.363125
# objectives.horde.first_diff                          0.019685
# objectives.inhibitor.first_diff                      0.580299
# objectives.inhibitor.kills_diff                      0.561658
# objectives.riftHerald.kills_diff                     0.160881
# objectives.tower.first_diff                          0.190791
# objectives.tower.kills_diff                          0.599971
# ping_diff                                            0.234420
#
#                                   objectives.baron.kills_diff  \
# blue_win                                             0.571851
# horde_kills                                          0.089052
# ward_diff                                            0.109734
# vision_score_diff                                    0.371451
# objectives.baron.first_diff                          0.889625
# objectives.baron.kills_diff                          1.000000
# objectives.champion.first_diff                       0.080740
# objectives.champion.kills_diff                       0.519652
# objectives.dragon.first_diff                         0.090527
# objectives.dragon.kills_diff                         0.371023
# objectives.horde.first_diff                          0.015308
# objectives.inhibitor.first_diff                      0.572059
# objectives.inhibitor.kills_diff                      0.600398
# objectives.riftHerald.kills_diff                     0.143884
# objectives.tower.first_diff                          0.177154
# objectives.tower.kills_diff                          0.601085
# ping_diff                                            0.242140
#
#                                   objectives.champion.first_diff  \
# blue_win                                                0.209457
# horde_kills                                             0.178579
# ward_diff                                               0.083377
# vision_score_diff                                       0.128507
# objectives.baron.first_diff                             0.092570
# objectives.baron.kills_diff                             0.080740
# objectives.champion.first_diff                          1.000000
# objectives.champion.kills_diff                          0.264641
# objectives.dragon.first_diff                            0.112307
# objectives.dragon.kills_diff                            0.165227
# objectives.horde.first_diff                             0.084311
# objectives.inhibitor.first_diff                         0.128554
# objectives.inhibitor.kills_diff                         0.126237
# objectives.riftHerald.kills_diff                        0.147400
# objectives.tower.first_diff                             0.200067
# objectives.tower.kills_diff                             0.189966
# ping_diff                                               0.099301
#
#                                   objectives.champion.kills_diff  \
# blue_win                                                0.844246
# horde_kills                                             0.281182
# ward_diff                                               0.219527
# vision_score_diff                                       0.522768
# objectives.baron.first_diff                             0.521553
# objectives.baron.kills_diff                             0.519652
# objectives.champion.first_diff                          0.264641
# objectives.champion.kills_diff                          1.000000
# objectives.dragon.first_diff                            0.260481
# objectives.dragon.kills_diff                            0.599333
# objectives.horde.first_diff                             0.086313
# objectives.inhibitor.first_diff                         0.655291
# objectives.inhibitor.kills_diff                         0.622844
# objectives.riftHerald.kills_diff                        0.379923
# objectives.tower.first_diff                             0.440628
# objectives.tower.kills_diff                             0.801964
# ping_diff                                               0.324716
#
#                                   objectives.dragon.first_diff  \
# blue_win                                              0.243997
# horde_kills                                           0.026022
# ward_diff                                             0.104373
# vision_score_diff                                     0.188003
# objectives.baron.first_diff                           0.097870
# objectives.baron.kills_diff                           0.090527
# objectives.champion.first_diff                        0.112307
# objectives.champion.kills_diff                        0.260481
# objectives.dragon.first_diff                          1.000000
# objectives.dragon.kills_diff                          0.608582
# objectives.horde.first_diff                          -0.025115
# objectives.inhibitor.first_diff                       0.142561
# objectives.inhibitor.kills_diff                       0.141846
# objectives.riftHerald.kills_diff                      0.137053
# objectives.tower.first_diff                           0.168057
# objectives.tower.kills_diff                           0.212846
# ping_diff                                             0.117573
#
#                                   objectives.dragon.kills_diff  \
# blue_win                                              0.575152
# horde_kills                                           0.149250
# ward_diff                                             0.170814
# vision_score_diff                                     0.428928
# objectives.baron.first_diff                           0.363125
# objectives.baron.kills_diff                           0.371023
# objectives.champion.first_diff                        0.165227
# objectives.champion.kills_diff                        0.599333
# objectives.dragon.first_diff                          0.608582
# objectives.dragon.kills_diff                          1.000000
# objectives.horde.first_diff                           0.040076
# objectives.inhibitor.first_diff                       0.469072
# objectives.inhibitor.kills_diff                       0.471613
# objectives.riftHerald.kills_diff                      0.216339
# objectives.tower.first_diff                           0.304449
# objectives.tower.kills_diff                           0.562628
# ping_diff                                             0.248390
#
#                                   objectives.horde.first_diff  \
# blue_win                                             0.100173
# horde_kills                                          0.657438
# ward_diff                                            0.059074
# vision_score_diff                                    0.084155
# objectives.baron.first_diff                          0.019685
# objectives.baron.kills_diff                          0.015308
# objectives.champion.first_diff                       0.084311
# objectives.champion.kills_diff                       0.086313
# objectives.dragon.first_diff                        -0.025115
# objectives.dragon.kills_diff                         0.040076
# objectives.horde.first_diff                          1.000000
# objectives.inhibitor.first_diff                      0.090459
# objectives.inhibitor.kills_diff                      0.085845
# objectives.riftHerald.kills_diff                     0.124911
# objectives.tower.first_diff                          0.172861
# objectives.tower.kills_diff                          0.138772
# ping_diff                                            0.035602
#
#                                   objectives.inhibitor.first_diff  \
# blue_win                                                 0.707649
# horde_kills                                              0.204648
# ward_diff                                                0.119368
# vision_score_diff                                        0.442314
# objectives.baron.first_diff                              0.580299
# objectives.baron.kills_diff                              0.572059
# objectives.champion.first_diff                           0.128554
# objectives.champion.kills_diff                           0.655291
# objectives.dragon.first_diff                             0.142561
# objectives.dragon.kills_diff                             0.469072
# objectives.horde.first_diff                              0.090459
# objectives.inhibitor.first_diff                          1.000000
# objectives.inhibitor.kills_diff                          0.844112
# objectives.riftHerald.kills_diff                         0.274607
# objectives.tower.first_diff                              0.321732
# objectives.tower.kills_diff                              0.832719
# ping_diff                                                0.231290
#
#                                   objectives.inhibitor.kills_diff  \
# blue_win                                                 0.698330
# horde_kills                                              0.193885
# ward_diff                                                0.107689
# vision_score_diff                                        0.450561
# objectives.baron.first_diff                              0.561658
# objectives.baron.kills_diff                              0.600398
# objectives.champion.first_diff                           0.126237
# objectives.champion.kills_diff                           0.622844
# objectives.dragon.first_diff                             0.141846
# objectives.dragon.kills_diff                             0.471613
# objectives.horde.first_diff                              0.085845
# objectives.inhibitor.first_diff                          0.844112
# objectives.inhibitor.kills_diff                          1.000000
# objectives.riftHerald.kills_diff                         0.258976
# objectives.tower.first_diff                              0.309239
# objectives.tower.kills_diff                              0.851548
# ping_diff                                                0.221899
#
#                                   objectives.riftHerald.kills_diff  \
# blue_win                                                  0.341810
# horde_kills                                               0.274709
# ward_diff                                                 0.123460
# vision_score_diff                                         0.243571
# objectives.baron.first_diff                               0.160881
# objectives.baron.kills_diff                               0.143884
# objectives.champion.first_diff                            0.147400
# objectives.champion.kills_diff                            0.379923
# objectives.dragon.first_diff                              0.137053
# objectives.dragon.kills_diff                              0.216339
# objectives.horde.first_diff                               0.124911
# objectives.inhibitor.first_diff                           0.274607
# objectives.inhibitor.kills_diff                           0.258976
# objectives.riftHerald.kills_diff                          1.000000
# objectives.tower.first_diff                               0.325968
# objectives.tower.kills_diff                               0.383311
# ping_diff                                                 0.156469
#
#                                   objectives.tower.first_diff  \
# blue_win                                             0.430941
# horde_kills                                          0.331422
# ward_diff                                            0.118371
# vision_score_diff                                    0.313140
# objectives.baron.first_diff                          0.190791
# objectives.baron.kills_diff                          0.177154
# objectives.champion.first_diff                       0.200067
# objectives.champion.kills_diff                       0.440628
# objectives.dragon.first_diff                         0.168057
# objectives.dragon.kills_diff                         0.304449
# objectives.horde.first_diff                          0.172861
# objectives.inhibitor.first_diff                      0.321732
# objectives.inhibitor.kills_diff                      0.309239
# objectives.riftHerald.kills_diff                     0.325968
# objectives.tower.first_diff                          1.000000
# objectives.tower.kills_diff                          0.482743
# ping_diff                                            0.146352
#
#                                   objectives.tower.kills_diff  ping_diff
# blue_win                                             0.854963   0.309015
# horde_kills                                          0.307107   0.116982
# ward_diff                                            0.158375   0.164038
# vision_score_diff                                    0.526480   0.220722
# objectives.baron.first_diff                          0.599971   0.234420
# objectives.baron.kills_diff                          0.601085   0.242140
# objectives.champion.first_diff                       0.189966   0.099301
# objectives.champion.kills_diff                       0.801964   0.324716
# objectives.dragon.first_diff                         0.212846   0.117573
# objectives.dragon.kills_diff                         0.562628   0.248390
# objectives.horde.first_diff                          0.138772   0.035602
# objectives.inhibitor.first_diff                      0.832719   0.231290
# objectives.inhibitor.kills_diff                      0.851548   0.221899
# objectives.riftHerald.kills_diff                     0.383311   0.156469
# objectives.tower.first_diff                          0.482743   0.146352
# objectives.tower.kills_diff                          1.000000   0.282858
# ping_diff                                            0.282858   1.000000

# %%
data_diff.corr()['objectives.champion.first_diff']
# Out:
# blue_win                            0.209457
# horde_kills                         0.178579
# ward_diff                           0.083377
# vision_score_diff                   0.128507
# objectives.baron.first_diff         0.092570
# objectives.baron.kills_diff         0.080740
# objectives.champion.first_diff      1.000000
# objectives.champion.kills_diff      0.264641
# objectives.dragon.first_diff        0.112307
# objectives.dragon.kills_diff        0.165227
# objectives.horde.first_diff         0.084311
# objectives.inhibitor.first_diff     0.128554
# objectives.inhibitor.kills_diff     0.126237
# objectives.riftHerald.kills_diff    0.147400
# objectives.tower.first_diff         0.200067
# objectives.tower.kills_diff         0.189966
# ping_diff                           0.099301
# Name: objectives.champion.first_diff, dtype: float64

# %%
sns.heatmap(data_diff.corr())
# Out:
# <Axes: >

# %%
corr_matrix = data_diff.corr()
np.fill_diagonal(corr_matrix.values, np.nan)

# %%
corr_matrix
# Out:
#                                   blue_win  horde_kills  ward_diff  \
# blue_win                               NaN     0.270790   0.162248
# horde_kills                       0.270790          NaN   0.130632
# ward_diff                         0.162248     0.130632        NaN
# vision_score_diff                 0.491109     0.213825   0.281629
# objectives.baron.first_diff       0.549484     0.098641   0.113357
# objectives.baron.kills_diff       0.571851     0.089052   0.109734
# objectives.champion.first_diff    0.209457     0.178579   0.083377
# objectives.champion.kills_diff    0.844246     0.281182   0.219527
# objectives.dragon.first_diff      0.243997     0.026022   0.104373
# objectives.dragon.kills_diff      0.575152     0.149250   0.170814
# objectives.horde.first_diff       0.100173     0.657438   0.059074
# objectives.inhibitor.first_diff   0.707649     0.204648   0.119368
# objectives.inhibitor.kills_diff   0.698330     0.193885   0.107689
# objectives.riftHerald.kills_diff  0.341810     0.274709   0.123460
# objectives.tower.first_diff       0.430941     0.331422   0.118371
# objectives.tower.kills_diff       0.854963     0.307107   0.158375
# ping_diff                         0.309015     0.116982   0.164038
#
#                                   vision_score_diff  \
# blue_win                                   0.491109
# horde_kills                                0.213825
# ward_diff                                  0.281629
# vision_score_diff                               NaN
# objectives.baron.first_diff                0.358299
# objectives.baron.kills_diff                0.371451
# objectives.champion.first_diff             0.128507
# objectives.champion.kills_diff             0.522768
# objectives.dragon.first_diff               0.188003
# objectives.dragon.kills_diff               0.428928
# objectives.horde.first_diff                0.084155
# objectives.inhibitor.first_diff            0.442314
# objectives.inhibitor.kills_diff            0.450561
# objectives.riftHerald.kills_diff           0.243571
# objectives.tower.first_diff                0.313140
# objectives.tower.kills_diff                0.526480
# ping_diff                                  0.220722
#
#                                   objectives.baron.first_diff  \
# blue_win                                             0.549484
# horde_kills                                          0.098641
# ward_diff                                            0.113357
# vision_score_diff                                    0.358299
# objectives.baron.first_diff                               NaN
# objectives.baron.kills_diff                          0.889625
# objectives.champion.first_diff                       0.092570
# objectives.champion.kills_diff                       0.521553
# objectives.dragon.first_diff                         0.097870
# objectives.dragon.kills_diff                         0.363125
# objectives.horde.first_diff                          0.019685
# objectives.inhibitor.first_diff                      0.580299
# objectives.inhibitor.kills_diff                      0.561658
# objectives.riftHerald.kills_diff                     0.160881
# objectives.tower.first_diff                          0.190791
# objectives.tower.kills_diff                          0.599971
# ping_diff                                            0.234420
#
#                                   objectives.baron.kills_diff  \
# blue_win                                             0.571851
# horde_kills                                          0.089052
# ward_diff                                            0.109734
# vision_score_diff                                    0.371451
# objectives.baron.first_diff                          0.889625
# objectives.baron.kills_diff                               NaN
# objectives.champion.first_diff                       0.080740
# objectives.champion.kills_diff                       0.519652
# objectives.dragon.first_diff                         0.090527
# objectives.dragon.kills_diff                         0.371023
# objectives.horde.first_diff                          0.015308
# objectives.inhibitor.first_diff                      0.572059
# objectives.inhibitor.kills_diff                      0.600398
# objectives.riftHerald.kills_diff                     0.143884
# objectives.tower.first_diff                          0.177154
# objectives.tower.kills_diff                          0.601085
# ping_diff                                            0.242140
#
#                                   objectives.champion.first_diff  \
# blue_win                                                0.209457
# horde_kills                                             0.178579
# ward_diff                                               0.083377
# vision_score_diff                                       0.128507
# objectives.baron.first_diff                             0.092570
# objectives.baron.kills_diff                             0.080740
# objectives.champion.first_diff                               NaN
# objectives.champion.kills_diff                          0.264641
# objectives.dragon.first_diff                            0.112307
# objectives.dragon.kills_diff                            0.165227
# objectives.horde.first_diff                             0.084311
# objectives.inhibitor.first_diff                         0.128554
# objectives.inhibitor.kills_diff                         0.126237
# objectives.riftHerald.kills_diff                        0.147400
# objectives.tower.first_diff                             0.200067
# objectives.tower.kills_diff                             0.189966
# ping_diff                                               0.099301
#
#                                   objectives.champion.kills_diff  \
# blue_win                                                0.844246
# horde_kills                                             0.281182
# ward_diff                                               0.219527
# vision_score_diff                                       0.522768
# objectives.baron.first_diff                             0.521553
# objectives.baron.kills_diff                             0.519652
# objectives.champion.first_diff                          0.264641
# objectives.champion.kills_diff                               NaN
# objectives.dragon.first_diff                            0.260481
# objectives.dragon.kills_diff                            0.599333
# objectives.horde.first_diff                             0.086313
# objectives.inhibitor.first_diff                         0.655291
# objectives.inhibitor.kills_diff                         0.622844
# objectives.riftHerald.kills_diff                        0.379923
# objectives.tower.first_diff                             0.440628
# objectives.tower.kills_diff                             0.801964
# ping_diff                                               0.324716
#
#                                   objectives.dragon.first_diff  \
# blue_win                                              0.243997
# horde_kills                                           0.026022
# ward_diff                                             0.104373
# vision_score_diff                                     0.188003
# objectives.baron.first_diff                           0.097870
# objectives.baron.kills_diff                           0.090527
# objectives.champion.first_diff                        0.112307
# objectives.champion.kills_diff                        0.260481
# objectives.dragon.first_diff                               NaN
# objectives.dragon.kills_diff                          0.608582
# objectives.horde.first_diff                          -0.025115
# objectives.inhibitor.first_diff                       0.142561
# objectives.inhibitor.kills_diff                       0.141846
# objectives.riftHerald.kills_diff                      0.137053
# objectives.tower.first_diff                           0.168057
# objectives.tower.kills_diff                           0.212846
# ping_diff                                             0.117573
#
#                                   objectives.dragon.kills_diff  \
# blue_win                                              0.575152
# horde_kills                                           0.149250
# ward_diff                                             0.170814
# vision_score_diff                                     0.428928
# objectives.baron.first_diff                           0.363125
# objectives.baron.kills_diff                           0.371023
# objectives.champion.first_diff                        0.165227
# objectives.champion.kills_diff                        0.599333
# objectives.dragon.first_diff                          0.608582
# objectives.dragon.kills_diff                               NaN
# objectives.horde.first_diff                           0.040076
# objectives.inhibitor.first_diff                       0.469072
# objectives.inhibitor.kills_diff                       0.471613
# objectives.riftHerald.kills_diff                      0.216339
# objectives.tower.first_diff                           0.304449
# objectives.tower.kills_diff                           0.562628
# ping_diff                                             0.248390
#
#                                   objectives.horde.first_diff  \
# blue_win                                             0.100173
# horde_kills                                          0.657438
# ward_diff                                            0.059074
# vision_score_diff                                    0.084155
# objectives.baron.first_diff                          0.019685
# objectives.baron.kills_diff                          0.015308
# objectives.champion.first_diff                       0.084311
# objectives.champion.kills_diff                       0.086313
# objectives.dragon.first_diff                        -0.025115
# objectives.dragon.kills_diff                         0.040076
# objectives.horde.first_diff                               NaN
# objectives.inhibitor.first_diff                      0.090459
# objectives.inhibitor.kills_diff                      0.085845
# objectives.riftHerald.kills_diff                     0.124911
# objectives.tower.first_diff                          0.172861
# objectives.tower.kills_diff                          0.138772
# ping_diff                                            0.035602
#
#                                   objectives.inhibitor.first_diff  \
# blue_win                                                 0.707649
# horde_kills                                              0.204648
# ward_diff                                                0.119368
# vision_score_diff                                        0.442314
# objectives.baron.first_diff                              0.580299
# objectives.baron.kills_diff                              0.572059
# objectives.champion.first_diff                           0.128554
# objectives.champion.kills_diff                           0.655291
# objectives.dragon.first_diff                             0.142561
# objectives.dragon.kills_diff                             0.469072
# objectives.horde.first_diff                              0.090459
# objectives.inhibitor.first_diff                               NaN
# objectives.inhibitor.kills_diff                          0.844112
# objectives.riftHerald.kills_diff                         0.274607
# objectives.tower.first_diff                              0.321732
# objectives.tower.kills_diff                              0.832719
# ping_diff                                                0.231290
#
#                                   objectives.inhibitor.kills_diff  \
# blue_win                                                 0.698330
# horde_kills                                              0.193885
# ward_diff                                                0.107689
# vision_score_diff                                        0.450561
# objectives.baron.first_diff                              0.561658
# objectives.baron.kills_diff                              0.600398
# objectives.champion.first_diff                           0.126237
# objectives.champion.kills_diff                           0.622844
# objectives.dragon.first_diff                             0.141846
# objectives.dragon.kills_diff                             0.471613
# objectives.horde.first_diff                              0.085845
# objectives.inhibitor.first_diff                          0.844112
# objectives.inhibitor.kills_diff                               NaN
# objectives.riftHerald.kills_diff                         0.258976
# objectives.tower.first_diff                              0.309239
# objectives.tower.kills_diff                              0.851548
# ping_diff                                                0.221899
#
#                                   objectives.riftHerald.kills_diff  \
# blue_win                                                  0.341810
# horde_kills                                               0.274709
# ward_diff                                                 0.123460
# vision_score_diff                                         0.243571
# objectives.baron.first_diff                               0.160881
# objectives.baron.kills_diff                               0.143884
# objectives.champion.first_diff                            0.147400
# objectives.champion.kills_diff                            0.379923
# objectives.dragon.first_diff                              0.137053
# objectives.dragon.kills_diff                              0.216339
# objectives.horde.first_diff                               0.124911
# objectives.inhibitor.first_diff                           0.274607
# objectives.inhibitor.kills_diff                           0.258976
# objectives.riftHerald.kills_diff                               NaN
# objectives.tower.first_diff                               0.325968
# objectives.tower.kills_diff                               0.383311
# ping_diff                                                 0.156469
#
#                                   objectives.tower.first_diff  \
# blue_win                                             0.430941
# horde_kills                                          0.331422
# ward_diff                                            0.118371
# vision_score_diff                                    0.313140
# objectives.baron.first_diff                          0.190791
# objectives.baron.kills_diff                          0.177154
# objectives.champion.first_diff                       0.200067
# objectives.champion.kills_diff                       0.440628
# objectives.dragon.first_diff                         0.168057
# objectives.dragon.kills_diff                         0.304449
# objectives.horde.first_diff                          0.172861
# objectives.inhibitor.first_diff                      0.321732
# objectives.inhibitor.kills_diff                      0.309239
# objectives.riftHerald.kills_diff                     0.325968
# objectives.tower.first_diff                               NaN
# objectives.tower.kills_diff                          0.482743
# ping_diff                                            0.146352
#
#                                   objectives.tower.kills_diff  ping_diff
# blue_win                                             0.854963   0.309015
# horde_kills                                          0.307107   0.116982
# ward_diff                                            0.158375   0.164038
# vision_score_diff                                    0.526480   0.220722
# objectives.baron.first_diff                          0.599971   0.234420
# objectives.baron.kills_diff                          0.601085   0.242140
# objectives.champion.first_diff                       0.189966   0.099301
# objectives.champion.kills_diff                       0.801964   0.324716
# objectives.dragon.first_diff                         0.212846   0.117573
# objectives.dragon.kills_diff                         0.562628   0.248390
# objectives.horde.first_diff                          0.138772   0.035602
# objectives.inhibitor.first_diff                      0.832719   0.231290
# objectives.inhibitor.kills_diff                      0.851548   0.221899
# objectives.riftHerald.kills_diff                     0.383311   0.156469
# objectives.tower.first_diff                          0.482743   0.146352
# objectives.tower.kills_diff                               NaN   0.282858
# ping_diff                                            0.282858        NaN

# %%
plt.barh(corr_matrix.vision_score_diff.index, corr_matrix.vision_score_diff.values)
# Out:
# <BarContainer object of 17 artists>

# %% [markdown]
# ### 시야 가설
# - 예상했던 것보다 다른 부분들과 시야 점수와의 상관관계가 낮음
# - 그러나 타워 제거나 챔피언 킬에는 0.5 이상의 상관관계를 보여줌
# - 승리와도 거의 0.5에 가까운 상관관계를 보여줌

# %%
def visual(data, colname):
    win = data[colname][data.blue_win == 1]
    lose = data[colname][data.blue_win == 0]
    
    plt.title(colname)
    plt.hist(win, label="win", alpha=0.5)
    plt.hist(lose, label="lose", alpha=0.5)
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### 시각화
# - 승리 여부에 따른 feature의 분포 시각화

# %%
for idx, i in enumerate(data_diff.columns):
    if idx == 0:
        pass
    else:
        visual(data_diff, i)

# %% [markdown]
# ### 시각화
# - 시각화를 해본 결과 타워의 철거갯수 차이가 승리 여부에 따라 가장 극명하게 나뉘어짐
# - 예상했던 것과 달리 와드 구매 갯수와 핑의 횟수 차이는 승리에 따라 큰 차이를 보여주지 않음

# %%
plt.barh(corr_matrix.ping_diff.index, corr_matrix.ping_diff.values)
# Out:
# <BarContainer object of 17 artists>

# %% [markdown]
# ### 핑 가설
# - 예상했던 것과 달리 핑과 승리의 상관관계가 낮음
# - 하지만 진 팀이 비교적 더 많은 핑을 치는 것으로 시각화를 통해 추정함

# %%
plt.barh(corr_matrix.horde_kills.index, corr_matrix.horde_kills.values)
# Out:
# <BarContainer object of 17 artists>

# %%
plt.barh(corr_matrix['objectives.dragon.kills_diff'].index, corr_matrix['objectives.dragon.kills_diff'].values)
# Out:
# <BarContainer object of 17 artists>

# %% [markdown]
# ## 공허 유충
# - 예상했던 것과 달리 공허 유충을 많이 먹는 것과 승리와의 상관관계는 용을 먹는 것보다 낮음
# - 이를 통해 여전히 용이 공허 유충보다 중요하다고 추정됨

# %% [markdown]
# ### 모델링
# - 랜덤포레스트 모델을 사용하여 분류 진행

# %%
train_x, test_x, train_y, test_y = train_test_split(data_diff.drop('blue_win', axis=1), data_diff.blue_win,
                                                    train_size=0.3, random_state=42)

# %%
rdf = RandomForestClassifier(random_state=42)

# %%
rdf.fit(train_x, train_y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred = rdf.predict(test_x)

# %%
f1_score(test_y, pred)
# Out:
# 0.9742517317997648
